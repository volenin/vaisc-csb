# %% [markdown]
# # Table of Contents
# - [Setup](#setup)
# - [Package installs](#package-installs)
# - [Imports](#imports)
# - [Authentication and Google Cloud settings](#authentication-and-gcp-settings)
# - [Global variables](#global-variables)
# - [Retail API wrappers](#retail-api-wrappers)
#   - [List Products](#list-products)
#   - [Search / Browse](#search--browse)
#   - [Recommendations](#recommendations)
# - [Utils](#utils)
# - [Tests](#tests)

# %% [markdown]
# # Overview
# This notebook demonstrates how to use the Google Cloud Retail API for product search, recommendations, and event analysis. Follow the steps below to set up your environment, authenticate, and explore the API.

# %% [markdown]
# # Setup
# Let's get started by preparing your environment. We'll begin with authentication and configuration, which are required for all subsequent API calls.

# %% [markdown]
# ## Package installs
# Install all required Python packages. Run this cell only once after starting a new kernel.

# %%
# %pip install google google-cloud-retail google-cloud-storage google-cloud-bigquery pandas
# %pip install google-cloud-bigquery-storage pyarrow tqdm bigquery-magics
# %pip install google-cloud-bigquery[pandas] jupyterlab
# %pip install fsspec gcsfs
# %pip install matplotlib seaborn plotly
# %pip install --upgrade ipython-sql
# Out:
# Requirement already satisfied: google in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (3.0.0)
# Requirement already satisfied: google-cloud-retail in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (2.1.0)
# Requirement already satisfied: google-cloud-storage in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (2.19.0)
# Requirement already satisfied: google-cloud-bigquery in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (3.33.0)
# Requirement already satisfied: pandas in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (2.2.3)
# Requirement already satisfied: beautifulsoup4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google) (4.13.4)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-retail) (2.24.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-retail) (2.40.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-retail) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-retail) (6.31.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-retail) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-retail) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-retail) (1.72.0rc1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-retail) (1.72.0rc1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-retail) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-retail) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-retail) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-retail) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-retail) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-retail) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-retail) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-retail) (0.6.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-storage) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: packaging>=24.2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: numpy>=1.22.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas) (2025.2)
# Requirement already satisfied: soupsieve>1.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from beautifulsoup4->google) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from beautifulsoup4->google) (4.13.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-cloud-bigquery-storage in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (2.31.0)
# Requirement already satisfied: pyarrow in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (20.0.0)
# Requirement already satisfied: tqdm in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (4.67.1)
# Requirement already satisfied: bigquery-magics in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-bigquery-storage) (2.24.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery-storage) (2.40.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery-storage) (1.26.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery-storage) (6.31.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-bigquery-storage) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-bigquery-storage) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-bigquery-storage) (1.72.0rc1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-bigquery-storage) (1.72.0rc1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery-storage) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery-storage) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery-storage) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-bigquery-storage) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-bigquery-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-bigquery-storage) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-bigquery-storage) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery-storage) (0.6.1)
# Requirement already satisfied: db-dtypes<2.0.0,>=0.3.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bigquery-magics) (1.4.3)
# Requirement already satisfied: google-cloud-bigquery<4.0.0,>=3.13.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bigquery-magics) (3.33.0)
# Requirement already satisfied: ipywidgets>=7.7.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bigquery-magics) (8.1.7)
# Requirement already satisfied: ipython>=7.23.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bigquery-magics) (8.18.1)
# Requirement already satisfied: ipykernel>=5.5.6 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bigquery-magics) (6.29.5)
# Requirement already satisfied: packaging>=20.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bigquery-magics) (25.0)
# Requirement already satisfied: pandas>=1.1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bigquery-magics) (2.2.3)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bigquery-magics) (1.9.1)
# Requirement already satisfied: numpy>=1.24.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from db-dtypes<2.0.0,>=0.3.0->bigquery-magics) (2.0.2)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery<4.0.0,>=3.13.0->bigquery-magics) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery<4.0.0,>=3.13.0->bigquery-magics) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery<4.0.0,>=3.13.0->bigquery-magics) (2.9.0.post0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery<4.0.0,>=3.13.0->bigquery-magics) (1.7.1)
# Requirement already satisfied: six>=1.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery<4.0.0,>=3.13.0->bigquery-magics) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=5.5.6->bigquery-magics) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=5.5.6->bigquery-magics) (1.8.14)
# Requirement already satisfied: jupyter-client>=6.1.12 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=5.5.6->bigquery-magics) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=5.5.6->bigquery-magics) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=5.5.6->bigquery-magics) (0.1.7)
# Requirement already satisfied: nest-asyncio in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=5.5.6->bigquery-magics) (1.6.0)
# Requirement already satisfied: psutil in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=5.5.6->bigquery-magics) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=5.5.6->bigquery-magics) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=5.5.6->bigquery-magics) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=5.5.6->bigquery-magics) (5.14.3)
# Requirement already satisfied: decorator in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->bigquery-magics) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->bigquery-magics) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->bigquery-magics) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->bigquery-magics) (2.19.1)
# Requirement already satisfied: stack-data in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->bigquery-magics) (0.6.3)
# Requirement already satisfied: typing-extensions in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->bigquery-magics) (4.13.2)
# Requirement already satisfied: exceptiongroup in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->bigquery-magics) (1.3.0)
# Requirement already satisfied: pexpect>4.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->bigquery-magics) (4.9.0)
# Requirement already satisfied: wcwidth in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->bigquery-magics) (0.2.13)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipywidgets>=7.7.1->bigquery-magics) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipywidgets>=7.7.1->bigquery-magics) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->bigquery-magics) (0.8.4)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=5.5.6->bigquery-magics) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel>=5.5.6->bigquery-magics) (3.21.0)
# Requirement already satisfied: platformdirs>=2.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.5.6->bigquery-magics) (4.3.8)
# Requirement already satisfied: pytz>=2020.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas>=1.1.0->bigquery-magics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas>=1.1.0->bigquery-magics) (2025.2)
# Requirement already satisfied: ptyprocess>=0.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->bigquery-magics) (0.7.0)
# Requirement already satisfied: setuptools in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pydata-google-auth>=1.5.0->bigquery-magics) (44.1.1)
# Requirement already satisfied: google-auth-oauthlib>=0.4.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pydata-google-auth>=1.5.0->bigquery-magics) (1.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth-oauthlib>=0.4.0->pydata-google-auth>=1.5.0->bigquery-magics) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.0->pydata-google-auth>=1.5.0->bigquery-magics) (3.2.2)
# Requirement already satisfied: executing>=1.2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->bigquery-magics) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->bigquery-magics) (3.0.0)
# Requirement already satisfied: pure-eval in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->bigquery-magics) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jupyterlab in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (4.4.3)
# Requirement already satisfied: google-cloud-bigquery[pandas] in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (3.33.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.11.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery[pandas]) (2.24.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (2.40.2)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0,>=2.21.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (2.32.3)
# Requirement already satisfied: pandas>=1.3.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (2.2.3)
# Requirement already satisfied: pandas-gbq>=0.26.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (0.29.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.47.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (1.72.0rc1)
# Requirement already satisfied: pyarrow>=3.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (20.0.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-bigquery[pandas]) (1.4.3)
# Requirement already satisfied: numpy>=1.24.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from db-dtypes<2.0.0,>=1.0.4->google-cloud-bigquery[pandas]) (2.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery[pandas]) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery[pandas]) (6.31.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core<3.0.0,>=2.11.1->google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery[pandas]) (1.26.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery[pandas]) (1.72.0rc1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery[pandas]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery[pandas]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-bigquery[pandas]) (4.9.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-resumable-media<3.0.0,>=2.0.0->google-cloud-bigquery[pandas]) (1.7.1)
# Requirement already satisfied: six>=1.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery[pandas]) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery[pandas]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery[pandas]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery[pandas]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.21.0->google-cloud-bigquery[pandas]) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-cloud-bigquery[pandas]) (0.6.1)
# Requirement already satisfied: async-lru>=1.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (8.7.0)
# Requirement already satisfied: ipykernel>=6.5.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (3.1.6)
# Requirement already satisfied: jupyter-core in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (44.1.1)
# Requirement already satisfied: tomli>=1.2.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (2.2.1)
# Requirement already satisfied: tornado>=6.2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (6.5.1)
# Requirement already satisfied: traitlets in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: anyio>=3.1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.22.0)
# Requirement already satisfied: pyzmq>=24 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (26.4.0)
# Requirement already satisfied: send2trash>=1.8.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.24.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (4.13.2)
# Requirement already satisfied: argon2-cffi-bindings in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from httpx>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.8.3->jupyterlab) (3.21.0)
# Requirement already satisfied: comm>=0.1.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=6.5.0->jupyterlab) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=6.5.0->jupyterlab) (8.18.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.7)
# Requirement already satisfied: nest-asyncio in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipykernel>=6.5.0->jupyterlab) (7.0.0)
# Requirement already satisfied: decorator in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.19.1)
# Requirement already satisfied: stack-data in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (4.9.0)
# Requirement already satisfied: wcwidth in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jinja2>=3.0.3->jupyterlab) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.25.1)
# Requirement already satisfied: platformdirs>=2.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-core->jupyterlab) (4.3.8)
# Requirement already satisfied: python-json-logger>=2.0.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: fqdn in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: uri-template in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.2.0)
# Requirement already satisfied: defusedxml in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: webencodings in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.21.1)
# Requirement already satisfied: pytz>=2020.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas>=1.3.0->google-cloud-bigquery[pandas]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas>=1.3.0->google-cloud-bigquery[pandas]) (2025.2)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas-gbq>=0.26.1->google-cloud-bigquery[pandas]) (1.9.1)
# Requirement already satisfied: google-auth-oauthlib>=0.7.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas-gbq>=0.26.1->google-cloud-bigquery[pandas]) (1.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth-oauthlib>=0.7.0->pandas-gbq>=0.26.1->google-cloud-bigquery[pandas]) (2.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.7.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.7.0->pandas-gbq>=0.26.1->google-cloud-bigquery[pandas]) (3.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (1.17.1)
# Requirement already satisfied: pycparser in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.22)
# Requirement already satisfied: soupsieve>1.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.9.0.20250516)
# Requirement already satisfied: executing>=1.2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.0)
# Requirement already satisfied: pure-eval in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: fsspec in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (2025.5.1)
# Requirement already satisfied: gcsfs in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (2025.5.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from gcsfs) (3.12.2)
# Requirement already satisfied: decorator>4.1.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from gcsfs) (5.2.1)
# Requirement already satisfied: google-auth>=1.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from gcsfs) (2.40.2)
# Requirement already satisfied: google-auth-oauthlib in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from gcsfs) (1.2.2)
# Requirement already satisfied: google-cloud-storage in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from gcsfs) (2.19.0)
# Requirement already satisfied: requests in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from gcsfs) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.20.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from multidict<7.0,>=4.5->aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (4.13.2)
# Requirement already satisfied: idna>=2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (3.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from rsa<5,>=3.1.4->google-auth>=1.2->gcsfs) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-auth-oauthlib->gcsfs) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests->gcsfs) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests->gcsfs) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from requests->gcsfs) (2025.4.26)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-storage->gcsfs) (2.24.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-storage->gcsfs) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-storage->gcsfs) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-cloud-storage->gcsfs) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (6.31.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (1.26.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (3.9.4)
# Requirement already satisfied: seaborn in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: plotly in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (6.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: pandas>=1.2 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from plotly) (1.41.0)
# Requirement already satisfied: zipp>=3.1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipython-sql in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython-sql) (3.16.0)
# Requirement already satisfied: ipython in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython-sql) (8.18.1)
# Requirement already satisfied: sqlalchemy>=2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython-sql) (2.0.41)
# Requirement already satisfied: sqlparse in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.13.2)
# Requirement already satisfied: decorator in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython->ipython-sql) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack-data in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: exceptiongroup in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython->ipython-sql) (1.3.0)
# Requirement already satisfied: pexpect>4.3 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: wcwidth in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages (from stack-data->ipython->ipython-sql) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Authentication and GCP settings
# Before we can interact with the Retail API, we need to authenticate with Google Cloud and set up our project context. This ensures all API calls are authorized and associated with the correct GCP project. If authentication fails, you'll be prompted to log in interactively. The `project_id` variable will be used throughout the notebook.
#
# **About `project_id` and Application Default Credentials (ADC):**
#
# - **`project_id`**: This uniquely identifies your Google Cloud project. All API requests, resource creation, and billing are tied to this project. Setting the correct `project_id` ensures your operations are performed in the intended environment and resources are properly tracked.
#
# - **Application Default Credentials (ADC)**: ADC is a mechanism that allows your code to automatically find and use your Google Cloud credentials. Running the `gcloud auth application-default login` command sets up ADC by generating credentials that client libraries (like the Retail API) can use to authenticate API calls on your behalf.
#
# **Why this matters:**
# Proper authentication and project selection are essential for secure, authorized access to Google Cloud resources. Without these, API calls will fail or may affect the wrong project. ADC simplifies credential management, especially in development and notebook environments.

# %%
# If needed, run this command to authenticate interactively
# !gcloud auth application-default login
# Out:
# https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login&state=zVLOy6BLjvmyMWCw0ORh8icDssZzAp&access_type=offline&code_challenge=0z9qDeHZhCLMQAfmiL-42Vo99qQFm79nSvJ5lmERkx4&code_challenge_method=S256
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login&state=zVLOy6BLjvmyMWCw0ORh8icDssZzAp&access_type=offline&code_challenge=0z9qDeHZhCLMQAfmiL-42Vo99qQFm79nSvJ5lmERkx4&code_challenge_method=S256
#
#
#
# Command killed by keyboard interrupt
#
# ^C

# %% [markdown]
# ## Imports
# Import all necessary libraries for API access, data analysis, and visualization.

# %%
import google.auth
from google.cloud.retail_v2 import SearchServiceClient, ProductServiceClient, PredictionServiceClient
from google.cloud.retail_v2.types import product, search_service, ListProductsRequest, SearchRequest, PredictRequest, UserEvent
from google.protobuf.field_mask_pb2 import FieldMask
from google.protobuf.json_format import MessageToDict
import pandas as pd
import http.client as http_client
import logging
import re
from IPython.display import display_html
from matplotlib import pyplot as plt
import seaborn as sns

# %load_ext bigquery_magics

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Authentication and Google Cloud settings
# Before you can interact with the Retail API, you must authenticate with Google Cloud and set up your project context. This ensures all API calls are authorized and associated with the correct Google Cloud project. If authentication fails, you'll be prompted to log in interactively. The `project_id` variable will be used throughout the notebook.
#
# **About `project_id` and Application Default Credentials (ADC)**
#
# - **`project_id`**: This uniquely identifies your Google Cloud project. All API requests, resource creation, and billing are tied to this project. Setting the correct `project_id` ensures your operations are performed in the intended environment and resources are properly tracked.
#
# - **Application Default Credentials (ADC)**: ADC is a mechanism that allows your code to automatically find and use your Google Cloud credentials. Running the `gcloud auth application-default login` command sets up ADC by generating credentials that client libraries (like the Retail API) can use to authenticate API calls on your behalf.
#
# **Why this matters**
# Proper authentication and project selection are essential for secure, authorized access to Google Cloud resources. Without these, API calls will fail or may affect the wrong project. ADC simplifies credential management, especially in development and notebook environments.

# %%
# Authenticate with Google Cloud and get the default project ID
try:
  credentials, project_id = google.auth.default()
  print(f"Using project ID: {project_id}")
except google.auth.exceptions.DefaultCredentialsError:
  print("Google Cloud Authentication failed. Please configure your credentials.")
  print("You might need to run 'gcloud auth application-default login'")
  project_id = None # Set to None or a default

# If needed, run this command to authenticate interactively
# !gcloud auth application-default login
# Out:
# Using project ID: artilekt-vaisc-csb
# https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login&state=hGhSluG3Gqf7M1pDFLQPuWSIiDDMNz&access_type=offline&code_challenge=vp-2ZLKOZTDQIFqO1y8YkVHUBOMTlOrpolao8qaHpO0&code_challenge_method=S256
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=764086051850-6qr4p6gpi6hn506pt8ejuq83di341hur.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login&state=hGhSluG3Gqf7M1pDFLQPuWSIiDDMNz&access_type=offline&code_challenge=vp-2ZLKOZTDQIFqO1y8YkVHUBOMTlOrpolao8qaHpO0&code_challenge_method=S256
#
#
#
# Command killed by keyboard interrupt
#
# ^C

# %% [markdown]
# ## Global variables
# With authentication complete, let's define some key variables that will be used in all your API calls. These include resource names and placements, which specify the context for search and recommendation requests.
#
# **What is a placement?**
# A placement is a configuration resource in the Retail API that determines how and where a model is used for serving search or recommendation results. Placements define the context (such as search, browse, or recommendation) and can be customized for different pages or user experiences.
#
# **Why might you have multiple placements or branches?**
# - You may have different placements for various parts of your site or app, such as a homepage recommendation carousel, a category browse page, or a personalized search bar.
# - Multiple branches allow you to manage different versions of your product catalog (e.g., staging vs. production, or A/B testing different product sets).
#
# **Example scenarios:**
# - Using a "default_search" placement for general product search, and a "recently_viewed_default" placement for showing users their recently viewed items.
# - Having separate branches for testing new product data before rolling it out to all users, or for running experiments with different recommendation models.

# %%
# Authenticate with Google Cloud and get the default project ID
try:
  credentials, project_id = google.auth.default()
  print(f"Using project ID: {project_id}")
except google.auth.exceptions.DefaultCredentialsError:
  print("Google Cloud Authentication failed. Please configure your credentials.")
  print("You might need to run 'gcloud auth application-default login'")
  project_id = None # Set to None or a default
  
  
# Define the default placement for search and recommendations
DEFAULT_SEARCH = (
  f"projects/{project_id}/locations/global/catalogs/default_catalog/"
  "placements/default_search" # Use default_search unless you have a specific browse placement
)
RECENTLY_VIEWED_DEFAULT = (
  f"projects/{project_id}/locations/global/catalogs/default_catalog/"
  "placements/recently_viewed_default"
)
DEFAULT_BRANCH = f"projects/{project_id}/locations/global/catalogs/default_catalog/branches/0"
# Out:
# Using project ID: artilekt-vaisc-csb

# %% [markdown]
# ## Utils
# To make your analysis easier, you'll use some utility functions for data conversion and HTTP logging. These will help you convert API responses to Pandas DataFrames for analysis and enable detailed logging for troubleshooting.

# %%
import pandas as pd
from google.protobuf.json_format import MessageToDict

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

def json2df(products_list):
  if products_list:
    products_dicts = [dict(sorted(MessageToDict(p._pb).items())) for p in products_list]
    df = pd.json_normalize(products_dicts)
    return df
  else:
    print("No products returned or an error occurred.")
    return pd.DataFrame()

from contextlib import contextmanager

@contextmanager
def http_logging(log_http: bool):
    """
    Context manager to enable/disable HTTP logging for Google API clients.
    Usage:
        with http_logging(log_http):
            # code that needs HTTP logging
    """
    import http.client as http_client
    import logging
    root_logger = logging.getLogger()
    original_http_debuglevel = http_client.HTTPConnection.debuglevel
    original_log_level = root_logger.level
    try:
        if log_http:
            print("\n--- [INFO] Enabling HTTP Logging (forcing REST transport) ---")
            logging.basicConfig()
            root_logger.setLevel(logging.DEBUG)
            http_client.HTTPConnection.debuglevel = 1
            print("--- [INFO] Using REST transport. ---")
        yield
    finally:
        if log_http:
            http_client.HTTPConnection.debuglevel = original_http_debuglevel
            root_logger.setLevel(original_log_level)
            print("--- [INFO] HTTP Logging & Root Log Level Restored ---")

# %% [markdown]
# # Retail API wrappers
# The following functions wrap the Google Cloud Retail API for listing products, searching, and getting recommendations.

# %% [markdown]
# ### About Retail API product listing
#
# The Retail API provides several core services for managing and interacting with your product catalog. Two key components referenced here are:
#
# - **ProductServiceClient**: This is the main client for interacting with product resources in your catalog. It allows you to list, create, update, and delete products. When you want to retrieve a list of products (optionally filtered by category or other attributes), you use this client.
#
# - **ListProductsRequest**: This is the request object you pass to the `list_products` method of `ProductServiceClient`. It specifies parameters such as which catalog branch to query, filters to apply, how many products to return per page, and which fields to include in the response.
#
# #### Business use case
#
# Calling the List Products API is essential for:
# - **Catalog validation**: Ensuring your product data is correctly ingested and available.
# - **Building product listings**: Powering category pages, admin dashboards, or inventory management tools.
# - **Data preparation**: Exporting product data for analytics, reporting, or downstream processing.
#
# This API is different from the **Search** and **Predict** APIs:
# - **ListProducts** is a direct, unpersonalized retrieval of catalog items, optionally filtered by category or other attributes.
# - **Search** provides full-text, faceted, and personalized search results, optimized for end-user queries.
# - **Predict** generates personalized recommendations based on user events and context.
#
# #### Key parameters
#
# When creating a `ListProductsRequest` and `ProductServiceClient`, you can specify:
#
# - **parent**: The resource name of the branch to list products from (e.g., `projects/{project_id}/locations/global/catalogs/default_catalog/branches/0`).
# - **filter**: A filter string to restrict results (e.g., by category, price, availability).
# - **page_size**: The maximum number of products to return in one call.
# - **read_mask**: Specifies which fields to include in the response (e.g., all fields or a subset).
# - **page_token**: For pagination, to retrieve the next set of results.
#
# When initializing the `ProductServiceClient`, you can also specify:
# - **transport**: Choose between `"grpc"` (default) or `"rest"` for debugging/logging.
# - **credentials**: Custom authentication credentials if needed.
#
# These parameters give you fine-grained control over how you access and manage your product catalog, making the List Products API a foundational tool for catalog operations.

# %%
def list_products(
  category: str,
  page_size: int = 10,
  log_http: bool = False
):
  """
  Lists products using the provided parameters to create a ListProductsRequest object.
  Args:
    category (str): Category name to filter products. If empty, returns all products.
    page_size (int): Number of products to return per page.
    log_http (bool): Enable HTTP logging for debugging.
  Returns:
    list: List of product objects or None if an error occurs.
  Raises:
    Exception: If the API call fails.
  """
  # Create a ProductServiceClient and build the request
  product_client = ProductServiceClient(transport="rest" if log_http else None)
  filter_string = ""  # No category filter by default
  read_mask = FieldMask(paths=["*"])
  try:
    with http_logging(log_http):
      list_products_request = ListProductsRequest(
        parent=DEFAULT_BRANCH,
        filter=filter_string,
        page_size=page_size,
        read_mask=read_mask
      )
      print("--- [INFO] Calling Retail API ListProducts... ---")
      products = []
      for product in product_client.list_products(request=list_products_request):
        # Optionally filter by category
        if category:
          product_categories = getattr(product, "categories", [])
          if isinstance(product_categories, str):
            product_categories = [product_categories]
          if category not in product_categories:
            continue
        products.append(product)
      if not products:
        print("No products found.")
      # else:
        # print(f"Found {len(products)} products.")
      return products
  except Exception as e:
    print(f"An error occurred during the list_products request: {e}")
    return None

# Example usage

# # List all products (no category filter)
# products = list_products(category="", page_size=50)
# print(f"Products (no category filter): {products}")

# # List products that have "Bags" in their categories
# products_bags = list_products(category="Bags", page_size=50)
# print(f"Products in 'Bags' category: {products_bags}")

# # Enable HTTP logging for debugging
# products_debug = list_products(category="Bags", page_size=50, log_http=True)
# print(f"Products with HTTP logging: {products_debug}")

# %% [markdown]
# ## Search/Browse
# With a list of products in hand, let's move on to searching and browsing. The Retail API supports full-text search and faceted browsing, allowing you to filter by category, use search queries, and personalize results with a visitor ID. This is the foundation for building search bars, category pages, and personalized shopping experiences. You'll use the results here for comparison and further analysis later in the lab.
#
# Key options:
# - `category`: Filter search results by category.
# - `query`: Enter a search term (e.g., "shoes").
# - `visitor_id`: Track user sessions for personalization.
# - `page_size`: Number of results per page.
#
# ---
#
# ### About `SearchServiceClient` and `SearchRequest`
#
# **`SearchServiceClient`** is the main client for interacting with the Retail API's search functionality. It is used to send search requests and receive results, supporting both full-text search and faceted browsing.
#
# **`SearchRequest`** is the request object passed to the client. It supports a variety of parameters:
#
# - **`placement`**: Specifies the serving configuration (e.g., default search placement).
# - **`visitor_id`**: Unique identifier for the user/session, enabling personalization.
# - **`query`**: The search term entered by the user (e.g., "shoes"). If omitted, the API performs a "browse" (category listing) instead of a search.
# - **`filter`**: Restricts results by attributes such as category, price, or custom fields (e.g., `categories: ANY("Bags")`).
# - **`page_size`**: Number of results to return per page.
# - **`page_token`**: For pagination, to fetch additional results.
# - **`order_by`**: Sort results by a specific field (e.g., price).
# - **`facet_specs`**: Request facet counts for fields (e.g., brand, color).
# - **`boost_spec`**: Boost or bury certain products in the results.
# - **`params`**: Additional custom parameters for advanced use cases.
# - **`page_categories`**: Used to provide context for the page (e.g., category pages).
#
# #### When to use which parameters?
#
# - **Search (with `query`)**:
#   Use when the user enters a search term in a search bar.
#   Example: `query="running shoes"`, `category="Shoes"`, `visitor_id="user123"`
#
# - **Browse (without `query`)**:
#   Use for category or collection pages, where you want to list products by category or attribute, but not by a search term.
#   Example: `category="Bags"`, `query=""`, `visitor_id="user123"`
#
# - **Personalization**:
#   Always provide a unique `visitor_id` to enable personalized ranking and recommendations.
#
# - **Faceting and filtering**:
#   Use `filter` and `facet_specs` to enable users to refine results by attributes like brand, price, or color.
#
# #### Use cases and scenarios
#
# - **Search bar**:
#   User types "sneakers" in the search bar.
#   → Set `query="sneakers"`, optionally filter by category or price.
#
# - **Category page (Browse)**:
#   User navigates to the "Bags" category.
#   → Set `category="Bags"`, leave `query=""` (empty string).
#
# - **Personalized results**:
#   Always pass a consistent `visitor_id` for each user/session to get personalized search and browse results.
#
# - **Faceted navigation**:
#   User selects filters like "brand: Nike" and "color: red".
#   → Add these as filters in the `filter` parameter.
#
# ---
#
# **Formal difference: Search vs. Browse**
#
# - **Search**:
#   - `query` is set (non-empty string).
#   - Returns results matching the search term, ranked by relevance.
#   - Used for keyword-based product discovery.
#
# - **Browse**:
#   - `query` is empty or omitted.
#   - Returns products based on category or other filters, not keyword relevance.
#   - Used for category pages, collection pages, or when users are exploring rather than searching.
#
# *Although both use the same API endpoint and client, the presence or absence of the `query` parameter formally distinguishes a "search" from a "browse" operation.*

# %%
def search_products(
  category: str,
  page_size: int = 10,
  query: str = "",
  visitor_id: str = "noname",
  log_http: bool = False
):
  """
  Executes a search using the provided parameters to create a SearchRequest object.
  Args:
    category (str): Category name to filter products.
    page_size (int): Number of products to return per page.
    query (str): Search query string.
    visitor_id (str): Visitor ID for the search event.
    log_http (bool): Enable HTTP logging for debugging.
  Returns:
    SearchResponse or None if an error occurs.
  Raises:
    Exception: If the API call fails.
  """
  try:
    with http_logging(log_http):
      search_client = SearchServiceClient(transport="rest" if log_http else None)
      search_request = SearchRequest(
        placement=DEFAULT_SEARCH,
        visitor_id=visitor_id,
        page_size=page_size,
        filter=f'categories: ANY("{category}")' if category else "",
        query=query,
        page_categories=[category]
      )
      print("--- [INFO] Calling Retail API Search... ---")
      search_response = search_client.search(search_request)
      print("\n---search response---")
      if not search_response.results:
        print("The search returned no matching results.")
      else:
        print(f"Found {search_response.total_size} results. Showing first {len(search_response.results)}:")
      return search_response
  except Exception as e:
    print(f"An error occurred during the search request: {e}")
    return None

# %% [markdown]
# ## Recommendations
# Now that you've explored and searched the catalog, let's see how the Retail API can generate personalized product recommendations. By providing user event data (such as a home-page view or product click), you can get tailored suggestions for each visitor. This is the engine behind features such as "recently viewed" or "you may also like". The recommendations generated here can be used to enhance user experience and drive engagement.
#
# **About `PredictionServiceClient` and `PredictRequest`:**
#
# - **`PredictionServiceClient`** is the main client for interacting with the Retail API's recommendation (predict) service. It is used to request product recommendations based on user events and context.
# - **`PredictRequest`** is the request object you pass to the client. It specifies the placement (type of recommendation), user event details, number of results, and additional parameters.
#
# **Key parameters you can pass:**
# - **`placement`**: Specifies the recommendation model and context (e.g., "recently_viewed_default", "similar_items").
# - **`user_event`**: A dictionary or object describing the user's action (e.g., home-page view, product detail view, add-to-cart) and context (visitor ID, product IDs, etc.).
# - **`visitor_id`**: Unique identifier for the user/session, enabling personalized recommendations.
# - **`page_size`**: Number of recommendations to return.
# - **`params`**: Additional custom parameters (e.g., `{"returnProduct": True}` to include product details in the response).
#
# **Use cases and scenarios:**
# - **Recently Viewed**: Show products the user has recently interacted with by sending a "home-page-view" or "detail-page-view" event.
# - **You May Also Like**: Recommend similar or complementary products based on a user's browsing or purchase history.
# - **Personalized Homepage**: Generate a set of recommendations for a returning visitor based on their past behavior.
# - **Cart Recommendations**: Suggest products to add to the cart based on current cart contents and user profile.
#
# Key options:
# - `user_event`: Describe the user's action and context.
# - `visitor_id`: Identify the user/session.
# - `page_size`: Number of recommendations to return.
#
# By customizing the `user_event` and `placement`, you can power a variety of recommendation scenarios tailored to your users' needs.

# %%
def predict_products(
  user_event: dict = None,
  page_size: int = 10,
  visitor_id: str = "noname",
  log_http: bool = False
):
  """
  Calls the Retail API Predict service to get product recommendations.
  Args:
    user_event (dict): User event dict. Must include at least 'visitor_id'.
    page_size (int): Number of results to return.
    visitor_id (str): Visitor ID for the event.
    log_http (bool): Enable HTTP logging for debugging.
  Returns:
    PredictResponse or None if an error occurs.
  Raises:
    Exception: If the API call fails.
  """
  placement = RECENTLY_VIEWED_DEFAULT
  if user_event is None:
    user_event = {
      "visitor_id": visitor_id,
      "event_type": "home-page-view"
    }
  try:
    with http_logging(log_http):
      predict_client = PredictionServiceClient(transport="rest" if log_http else None)
      user_event_obj = UserEvent(**user_event)
      predict_request = PredictRequest(
        placement=placement,
        user_event=user_event_obj,
        page_size=page_size,
        params={
          "returnProduct": True
        }
      )
      print("--- [INFO] Calling Retail API Predict... ---")
      predict_response = predict_client.predict(request=predict_request)
      if not predict_response.results:
        print("The predict call returned no recommendations.")
      else:
        print(f"Found {len(predict_response.results)} recommendations.")
      return predict_response
  except Exception as e:
    print(f"An error occurred during the predict request: {e}")
    return None

# %% [markdown]
# # Tests
#
# The previous sections focused on building convenience wrappers around the Retail APIs. In the following cells, you test these wrappers in practice. The first two tests are designed to compare the results of the ListProducts and Search APIs. This comparison demonstrates that the 'browse' (search without a query) returns results in a different order, as determined by the underlying ML model evaluation.

# %% [markdown]
# ## List products
# Example: List products in the 'Bags' category and display the first 5 results.

# %%
# Invoke list_products with 'Bags' category
products_list = list_products(category="Bags", page_size=50)
print("Results from list_products (category='Bags'):")
products_list_df = json2df(products_list[:5])
display(products_list_df)
# Out:
# --- [INFO] Calling Retail API ListProducts... ---
# Results from list_products (category='Bags'):
#    availability categories              id  \
# 0      IN_STOCK     [Bags]  GGCOGBJC100999
# 1  OUT_OF_STOCK     [Bags]  GGCOGBJD157199
# 2      IN_STOCK     [Bags]  GGOEABRB130499
# 3      IN_STOCK     [Bags]  GGOEGBBC122499
# 4  OUT_OF_STOCK     [Bags]  GGOEGBBD121999
#
#                                                                                                           images  \
# 0  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGCOGBJC100999.jpg'}]
# 1  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGCOGBJD157199.jpg'}]
# 2  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGOEABRB130499.jpg'}]
# 3  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGOEGBBC122499.jpg'}]
# 4  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGOEGBBD121999.jpg'}]
#
#                                                                                                 name  \
# 0  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGCOGBJC100999
# 1  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGCOGBJD157199
# 2  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGOEABRB130499
# 3  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGOEGBBC122499
# 4  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGOEGBBD121999
#
#   primaryProductId                           title     type  \
# 0   GGCOGBJC100999             #IamRemarkable Tote  PRIMARY
# 1   GGCOGBJD157199      Google Land & Sea Tote Bag  PRIMARY
# 2   GGOEABRB130499         Android Iconic Backpack  PRIMARY
# 3   GGOEGBBC122499  Google Campus Bike Carry Pouch  PRIMARY
# 4   GGOEGBBD121999      Google Striped Penny Pouch  PRIMARY
#
#                                                                                                   uri  \
# 0                     https://shop.googlemerchandisestore.com/Google+Redesign/Bags/IamRemarkable+Tote
# 1      https://shop.googlemerchandisestore.com/Google+Redesign/Lifestyle/Google+Land+and+Sea+Tote+Bag
# 2                https://shop.googlemerchandisestore.com/Google+Redesign/Bags/Android+Iconic+Backpack
# 3  https://shop.googlemerchandisestore.com/Google+Redesign/Bags/Google+Google+Campus+Bike+Carry+Pouch
# 4      https://shop.googlemerchandisestore.com/Google+Redesign/Bags/Google+Google+Striped+Penny+Pouch
#
#   priceInfo.currencyCode  priceInfo.price  priceInfo.originalPrice
# 0                    USD              8.0                      8.0
# 1                    USD             20.0                     20.0
# 2                    USD             25.0                     25.0
# 3                    USD              8.0                      8.0
# 4                    USD              9.0                      9.0

# %% [markdown]
# ## Browse products
# Example: Search for products in the 'Bags' category and display the first 5 results.

# %%
# Invoke search_products with 'Bags' category
products_search = list(search_products(category="Bags", page_size=50))
print("Results from search_products (category='Bags'):")
products_search_df = json2df(products_search[:5])
display(products_search_df)
# Out:
# --- [INFO] Calling Retail API Search... ---
#
# ---search response---
# Found 44 results. Showing first 44:
# Results from search_products (category='Bags'):
#                id  \
# 0  GGOEGBJC122399
# 1  GGOEGBBJ131999
# 2  GGOEGBJD143099
# 3  GGOEGBJJ171099
# 4  GGCOGBJD157199
#
#                                                                                         product.name  \
# 0  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGOEGBJC122399
# 1  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGOEGBBJ131999
# 2  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGOEGBJD143099
# 3  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGOEGBJJ171099
# 4  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGCOGBJD157199
#
#   product.categories                 product.title  \
# 0             [Bags]  Google Campus Bike Tote Navy
# 1             [Bags]      Google Cork Pencil Pouch
# 2             [Bags]     Google Austin Campus Tote
# 3             [Bags]            Google Campus Tote
# 4             [Bags]    Google Land & Sea Tote Bag
#
#   product.priceInfo.currencyCode  product.priceInfo.price  \
# 0                            USD                     11.0
# 1                            USD                      8.0
# 2                            USD                     11.0
# 3                            USD                     16.0
# 4                            USD                     20.0
#
#    product.priceInfo.originalPrice product.availability  \
# 0                             11.0             IN_STOCK
# 1                              8.0             IN_STOCK
# 2                             11.0             IN_STOCK
# 3                             16.0         OUT_OF_STOCK
# 4                             20.0         OUT_OF_STOCK
#
#                                                                                         product.uri  \
# 0  https://shop.googlemerchandisestore.com/Google+Redesign/Bags/Google+Google+Campus+Bike+Tote+Navy
# 1           https://shop.googlemerchandisestore.com/Google+Redesign/Office/Google+Cork+Pencil+Pouch
# 2            https://shop.googlemerchandisestore.com/Google+Redesign/Bags/Google+Austin+Campus+Tote
# 3                        https://shop.googlemerchandisestore.com/Google+Redesign/Google+Campus+Tote
# 4    https://shop.googlemerchandisestore.com/Google+Redesign/Lifestyle/Google+Land+and+Sea+Tote+Bag
#
#                                                                                                   product.images
# 0  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGOEGBJC122399.jpg'}]
# 1  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGOEGBBJ131999.jpg'}]
# 2  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGOEGBJD143099.jpg'}]
# 3         [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/noimage.jpg'}]
# 4  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGCOGBJD157199.jpg'}]

# %% [markdown]
# ## Compare results
# Compare the outputs of list_products and search_products side by side.

# %%
import pandas as pd
from IPython.display import display_html

max_rows = 5  # Set the maximum number of rows to display

# Create side-by-side comparison of products from list_products and search_products
products_list_df = json2df(list_products(category="Bags", page_size=50)[:max_rows])
products_search_df = json2df(list(search_products(category="Bags", page_size=50))[:max_rows])

# Extract only the 'title' column from each dataframe and rename for clarity
df1 = products_list_df[['id', 'title']].rename(columns={'id': 'list_products_id', 'title': 'list_products_title'})
df2 = products_search_df[['id', 'product.title']].rename(columns={'id': 'search_products_id', 'product.title': 'search_products_title'})

# Reset index to align rows side by side
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# Concatenate side by side
side_by_side = pd.concat([df1, df2], axis=1)

display(side_by_side)
# Out:
# --- [INFO] Calling Retail API ListProducts... ---
# --- [INFO] Calling Retail API Search... ---
#
# ---search response---
# Found 44 results. Showing first 44:
#   list_products_id             list_products_title search_products_id  \
# 0   GGCOGBJC100999             #IamRemarkable Tote     GGOEGBJC122399
# 1   GGCOGBJD157199      Google Land & Sea Tote Bag     GGOEGBBJ131999
# 2   GGOEABRB130499         Android Iconic Backpack     GGOEGBJD143099
# 3   GGOEGBBC122499  Google Campus Bike Carry Pouch     GGOEGBJJ171099
# 4   GGOEGBBD121999      Google Striped Penny Pouch     GGCOGBJD157199
#
#           search_products_title
# 0  Google Campus Bike Tote Navy
# 1      Google Cork Pencil Pouch
# 2     Google Austin Campus Tote
# 3            Google Campus Tote
# 4    Google Land & Sea Tote Bag

# %% [markdown]
# ## Get product details from BigQuery
# Example: Query product details for a specific product ID from BigQuery.
#
# The `%%bigquery` command is a "cell magic" available in IPython and Jupyter Notebook environments when the `google-cloud-bigquery` library and its `bigquery_magics` extension are loaded (usually via `%load_ext bigquery_magics`).
#
# **What it is:**
# Cell magics are special commands that start with `%%` and apply to the entire cell. The `%%bigquery` magic allows you to write and execute Google BigQuery SQL queries directly within a code cell, just as if you were using the BigQuery console or another SQL tool.
#
# **How it works:**
# When you execute a cell starting with `%%bigquery`:
# 1.  The magic command captures the rest of the cell's content as a SQL query.
# 2.  It uses the currently authenticated Google Cloud credentials (often Application Default Credentials, as set up earlier) and the default project ID to connect to BigQuery.
# 3.  It sends the SQL query to your BigQuery project for execution.
# 4.  By default, the results of the query are returned as a Pandas DataFrame and displayed in the notebook. You can also assign the result to a Python variable.
#
# **Usefulness in data analysis:**
# The `%%bigquery` magic is extremely useful for data analysis workflows within Jupyter Notebooks for several reasons:
# *   **Simplicity:** It allows data scientists and analysts to query vast datasets stored in BigQuery using familiar SQL syntax without writing extensive Python boilerplate code for client library setup, query execution, and result parsing.
# *   **Direct integration:** Results are typically loaded directly into Pandas DataFrames, making it seamless to transition from data retrieval to data manipulation, analysis, and visualization using Python's rich data science ecosystem.
# *   **Iterative exploration:** It facilitates quick, iterative exploration of data. You can rapidly run queries, inspect results, refine your SQL, and re-run, all within the interactive notebook environment.
# *   **Reproducibility:** SQL queries embedded in notebook cells are saved as part of the notebook, making the data retrieval step clear and reproducible.
# *   **Parameterization:** You can use Python variables within your SQL queries by prefixing them with `$` (e.g., `SELECT * FROM my_table WHERE column = $python_variable`), allowing for dynamic query generation.
#
# In the cell below, `%%bigquery` is used to fetch all columns (`SELECT *`) for a product with a specific `id` from the `retail.products` table in BigQuery. The result will be displayed as a table in the notebook output.

# %%
# %%bigquery
# SELECT * FROM `artilekt-vaisc-csb.retail.products` where id = 'GGOEGBJD122199'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 get_ipython().run_cell_magic('bigquery', '', "SELECT * FROM `${project_id}.retail.products` where id = 'GGOEGBJD122199'\n")
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/bigquery_magics/bigquery.py:470, in _cell_magic(line, query)
#     467 if engine == "bigframes":
#     468     return _query_with_bigframes(query, params, args)
# --> 470 return _query_with_pandas(query, params, args)
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/bigquery_magics/bigquery.py:556, in _query_with_pandas(query, params, args)
#     554 bq_client, bqstorage_client = _create_clients(args)
#     555 try:
# --> 556     return _make_bq_query(
#     557         query,
#     558         args=args,
#     559         params=params,
#     560         bq_client=bq_client,
#     561         bqstorage_client=bqstorage_client,
#     562     )
#     563 finally:
#     564     _close_transports(bq_client, bqstorage_client)
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/bigquery_magics/bigquery.py:768, in _make_bq_query(query, args, params, bq_client, bqstorage_client)
#     765     _create_dataset_if_necessary(bq_client, dataset_id)
#     767 try:
# --> 768     query_job = _run_query(bq_client, query, job_config=job_config)
#     769 except Exception as ex:
#     770     _handle_error(ex, args.destination_var)
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/bigquery_magics/bigquery.py:217, in _run_query(client, query, job_config)
#     194 """Runs a query while printing status updates
#     195
#     196 Args:
#    (...)
#     214     'bf633912-af2c-4780-b568-5d868058632b'
#     215 """
#     216 start_time = time.perf_counter()
# --> 217 query_job = client.query(query, job_config=job_config)
#     219 if job_config and job_config.dry_run:
#     220     return query_job
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/cloud/bigquery/client.py:3504, in Client.query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3493     return _job_helpers.query_jobs_query(
#    3494         self,
#    3495         query,
#    (...)
#    3501         job_retry,
#    3502     )
#    3503 elif api_method == enums.QueryApiMethod.INSERT:
# -> 3504     return _job_helpers.query_jobs_insert(
#    3505         self,
#    3506         query,
#    3507         job_config,
#    3508         job_id,
#    3509         job_id_prefix,
#    3510         location,
#    3511         project,
#    3512         retry,
#    3513         timeout,
#    3514         job_retry,
#    3515     )
#    3516 else:
#    3517     raise ValueError(f"Got unexpected value for api_method: {repr(api_method)}")
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/cloud/bigquery/_job_helpers.py:183, in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry)
#     180 if job_retry is not None:
#     181     do_query = google.cloud.bigquery.retry._DEFAULT_QUERY_JOB_INSERT_RETRY(do_query)
# --> 183 future = do_query()
#     185 # The future might be in a failed state now, but if it's
#     186 # unrecoverable, we'll find out when we ask for it's result, at which
#     187 # point, we may retry.
#     188 if not job_id_given:
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/cloud/bigquery/_job_helpers.py:139, in query_jobs_insert.<locals>.do_query()
#     136 query_job = job.QueryJob(job_ref, query, client=client, job_config=job_config)
#     138 try:
# --> 139     query_job._begin(retry=retry, timeout=timeout)
#     140 except core_exceptions.Conflict as create_exc:
#     141     # The thought is if someone is providing their own job IDs and they get
#     142     # their job ID generation wrong, this could end up returning results for
#     143     # the wrong query. We thus only try to recover if job ID was not given.
#     144     if job_id_given:
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/cloud/bigquery/job/query.py:1398, in QueryJob._begin(self, client, retry, timeout)
#    1378 """API call:  begin the job via a POST request
#    1379
#    1380 See
#    (...)
#    1394     ValueError: If the job has already begun.
#    1395 """
#    1397 try:
# -> 1398     super(QueryJob, self)._begin(client=client, retry=retry, timeout=timeout)
#    1399 except exceptions.GoogleAPICallError as exc:
#    1400     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1401         message=exc.message, location=self.location, job_id=self.job_id
#    1402     )
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/cloud/bigquery/job/base.py:780, in _AsyncJob._begin(self, client, retry, timeout)
#     777 # jobs.insert is idempotent because we ensure that every new
#     778 # job has an ID.
#     779 span_attributes = {"path": path}
# --> 780 api_response = client._call_api(
#     781     retry,
#     782     span_name="BigQuery.job.begin",
#     783     span_attributes=span_attributes,
#     784     job_ref=self,
#     785     method="POST",
#     786     path=path,
#     787     data=self.to_api_repr(),
#     788     timeout=timeout,
#     789 )
#     790 self._set_properties(api_response)
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/cloud/bigquery/client.py:843, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     839 if span_name is not None:
#     840     with create_span(
#     841         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     842     ):
# --> 843         return call()
#     845 return call()
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/google/auth/transport/requests.py:540, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     538 with TimeoutGuard(remaining_time) as guard:
#     539     _helpers.request_log(_LOGGER, method, url, data, headers)
# --> 540     response = super(AuthorizedSession, self).request(
#     541         method,
#     542         url,
#     543         data=data,
#     544         headers=request_headers,
#     545         timeout=timeout,
#     546         **kwargs
#     547     )
#     548 remaining_time = guard.remaining_timeout
#     550 # If the response indicated that the credentials needed to be
#     551 # refreshed, then refresh the credentials and re-attempt the
#     552 # request.
#     553 # A stored token may expire between the time it is retrieved and
#     554 # the time the request is made, so we may need to try twice.
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /c/Projects/Lab/vaisc/vaisc-csb/.venv/lib/python3.9/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.9/http/client.py:1347, in HTTPConnection.getresponse(self)
#    1345 try:
#    1346     try:
# -> 1347         response.begin()
#    1348     except ConnectionError:
#    1349         self.close()
#
# File /usr/lib/python3.9/http/client.py:307, in HTTPResponse.begin(self)
#     305 # read until we get a non-100 response
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#     309         break
#
# File /usr/lib/python3.9/http/client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#     270         raise LineTooLong("status line")
#
# File /usr/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /usr/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Identify user events associated with the products
#
# To effectively test the prediction functionality, you need relevant `visitorId`s. A good way to find these is by analyzing historical user events to see which visitors interacted with the products we're interested in.
#
# In this step, you focus on identifying visitors who have viewed products within the 'Bags' category. You previously listed and searched for products in this category (in cells 22, 24, and 26), and will now use those product IDs to filter a dataset of historical user events. This will give you a list of `visitorId`s that are likely to be relevant for generating personalized recommendations related to 'Bags'.
#
# To retrieve this data, you access a dump of user events that is stored in a Google Cloud Storage bucket. The following Python cell demonstrates how we can directly read this data (in JSON format) into a Pandas DataFrame. This showcases the versatility of Jupyter Notebooks for data analysis and testing, allowing us to seamlessly integrate data retrieval from cloud storage, data manipulation with Pandas, and interaction with APIs like the Retail API, all within a single environment.

# %%
df_events = pd.read_json('gs://artilekt-vaisc-csb_retail/recent_retail_events.json', lines=True)
df_events.head()

# Assume 'bag_products' is a list of product IDs you want to filter for
bag_products = ['GGCOGBJD157199', 'GGOEABRB130499', 'GGOEGBBJ131999']

# Extract product id from the first productDetails entry for each row
df_events['product_id'] = df_events['productDetails'].apply(
  lambda x: x[0]['product']['id'] if isinstance(x, list) and x and 'product' in x[0] and 'id' in x[0]['product'] else None
)

# Filter rows where product_id is in bag_products
if 'product_id' not in df_events.columns:
    print("'product_id' column not found in df_events. Check the structure of your input data.")
else:
    filtered = df_events[df_events['product_id'].isin(bag_products)][['visitorId', 'product_id']]
    
filtered.head()
# Out:
#                        visitorId      product_id
# 11    GA1.3.494294221.1619828856  GGOEABRB130499
# 297   GA1.3.294040182.1619872768  GGOEABRB130499
# 468   GA1.3.847874442.1619893172  GGOEABRB130499
# 706                           ""  GGOEABRB130499
# 740  GA1.3.1623205614.1614051318  GGOEABRB130499

# %% [markdown]
# ## Recommend a product
# Example: Get product recommendations for a specific visitor.

# %%
# Get the first visitorId from the filtered DataFrame
visitor_id = filtered['visitorId'].iloc[0]

# Invoke predict_products using the fetched visitor_id
predict_response = predict_products(visitor_id=visitor_id, page_size=5)

print("Results from predict_products:")
recommendations_df = json2df(predict_response.results)
display(recommendations_df)
# Out:
# --- [INFO] Calling Retail API Predict... ---
# Found 2 recommendations.
# Results from predict_products:
#                id metadata.product.primaryProductId  \
# 0  GGOEGBRJ114199                    GGOEGBRJ114199
# 1  GGOEABRB130499                    GGOEABRB130499
#
#                                                                                metadata.product.name  \
# 0  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGOEGBRJ114199
# 1  projects/72145653914/locations/global/catalogs/default_catalog/branches/0/products/GGOEABRB130499
#
#   metadata.product.categories   metadata.product.title metadata.product.id  \
# 0                      [Bags]  Google Utility BackPack      GGOEGBRJ114199
# 1                      [Bags]  Android Iconic Backpack      GGOEABRB130499
#
#                                    metadata.product.@type  \
# 0  type.googleapis.com/google.cloud.retail.v2main.Product
# 1  type.googleapis.com/google.cloud.retail.v2main.Product
#
#                                                                    metadata.product.uri  \
# 0  https://shop.googlemerchandisestore.com/Google+Redesign/Bags/Google+Utility+BackPack
# 1  https://shop.googlemerchandisestore.com/Google+Redesign/Bags/Android+Iconic+Backpack
#
#                                                                                          metadata.product.images  \
# 0  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGOEGBRJ114199.jpg'}]
# 1  [{'uri': 'https://shop.googlemerchandisestore.com/store/20160512512/assets/items/images/GGOEABRB130499.jpg'}]
#
#   metadata.product.type metadata.product.availability  \
# 0               PRIMARY                      IN_STOCK
# 1               PRIMARY                      IN_STOCK
#
#   metadata.product.priceInfo.currencyCode  metadata.product.priceInfo.price  \
# 0                                     USD                             120.0
# 1                                     USD                              25.0
#
#    metadata.product.priceInfo.originalPrice
# 0                                     120.0
# 1                                      25.0
